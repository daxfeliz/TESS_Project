# %% [markdown]
# # In this module, we will learn how to install Python 3, Anaconda, several Python packages and then learn the basics:
# - the Print command and strings, ints and floats
# - Variables, Lists, Dictionaries and Arrays
# - Functions and classes
# - Plotting basics with matplotlib

# %% [markdown]
# # 1) Download Python package manager, Anaconda
#
#
# [https://www.anaconda.com/distribution/](https://www.anaconda.com/distribution/)
#
# Python 2.7 is an older version many people still use,
# however many Python modules are now reducing support in
# favor of support Python 3.7. So let's download Python 3.
#
# This will automatically include Python as well as several Python modules ([See the full list here](https://docs.anaconda.com/anaconda/packages/old-pkg-lists/4.3.1/py35/)). Additionally, Anaconda includes pip and Jupyter Notebook (which this .ipynb file was created with!). Pip is how people managed their Python packages before Anaconda. Some custom Python modules require pip to install. You can read more about [pip here](https://realpython.com/what-is-pip/) but let's worry about that later.
#
# Once downloaded and installed, whenever you want to update your Python modules to the latest versions, you can just run these commands from the terminal:
#
# ```js
# conda update conda
# ```

# %% [markdown]
# # 2) Installing new Modules
# If you want to install a new module that is hosted by Anaconda, you can type in your command terminal:
# ```js
# conda install NameOfPackage
# ```
# And the package should be installed with all the necessary dependencies.

# %% [markdown]
# # 3) Here are a list of modules we'll be using for this summer and instructions to download and install them:
#
# * Numpy (included with Anaconda installation). Has a LOT of useful commands for mathematical operations and data manipulation.
#
# * Matplotlib (included with Anaconda installation). This is what you'll need to create figures and visualize your data.
#
# * Scipy (included with Anaconda installation). Has a lot of useful math commands.
#
# * Astropy (included with Anaconda installation). Contains many useful tools for Astronomy related tasks.
#
# * Lightkurve (VERY IMPORTANT!) Contains many useful commands for analyzing photometric data. [Read more about this custom Python module here](https://docs.lightkurve.org/index.html)
#     ```js
#     conda install --channel conda-forge lightkurve
#     ```
#
# * Transit Least Squares. A new method to detect planetary transits from time-series photometry. We'll talk more about this later.
#     ```js
#     pip install transitleastsquares
#     ```
#
# * Seaborn (optional). This can be used to make really beautiful figures.
#     ```js
#     conda install seaborn
#     ```
# * Exoplanet (optional). Another Custom package for analyzing photometric data. I'm still building tools with this that I'm not sure we'll need to use just yet.
#     ```js
#     pip install exoplanet
#     ```
# * PyMC3 (optional). Contains useful commands for Monte Carlo Markov Chains (MCMC). Not sure we'll need this yet.
#     ```js
#     conda install pymc3
#     ````
#
# # With all that installed, we should be good to go!

# %% [markdown]
# # 4) Now, let's start with some Python basics: Strings, Intergers and Floats.
#
# Unlike many other languages, a simple Python script does not require any sort of header information in the code. So, we can look at the standard programming example, Hello World, in Python (below). Here we're simply printing to screen. This also shows off the
# first Python function, print, which can be used to print strings or numbers.
# ```js
# print("Hello World!")
# ```
#
# When text is placed inside quotation marks (single or double), they are called a string (or str for short). A number, like 5, is called an interger (or int for short). A number with decimals, like 5.3, is called a float. You can see what types these objects are with the print and type commands:
# ```js
# print( type("Hello World") )
# print( type(5) )
# print( type(5.3) )
# ```

# %% [markdown]
# # 5) Variables, Lists, Dictionaries and Arrays
#
# ## Variables:
# Some languages require that every variable be defined by a variable type. In Python, defined variables are stored in memory. Below are a few examples:
# ```js
# x=42
# print(x+10)
# print(x/4)
# ```
#
# You can also add strings together with variables:
# ```js
# w="Hello"
# print(w + " world")
# ```
# ## Lists:
# The basic way for storing larger amounts of data in Python (and without using other modules like numpy) is Python's default option, lists. A list is, by its definition, one dimensional. If we'd like to store more dimensions, then we are using what are referred to as lists of lists. This is not the same thing as an array, which is what numpy will use. Let's take a look at what a list does.
#
# We'll start off with a nice simple list below. Here the list stores integers. Printing it back, we get exactly what we expect. However, because it's being treated as a list, not an array, it gets a little bit weird when we try to do addition or multiplication. Feel free to try changing the operations that we're using and see what causes errors, and what causes unexpected results.
# ```js
# x=[1, 2, 3]
# y=[4,5, 6]
# print(x)
# print(x*2)
# print(x+y)
# ```
#
# We can also set up a quick list if we want to using the range function. If we use just a single number, then we'll get a list of integers from 0 to 1 less than the number we gave it.
# ```js
# print( list(range(10)) )
# ```
# If we want a bit fancier of a list, then we can also include the number to start at (first parameter) and the step size (last parameter). All three of these have to be integers.
# ```js
# print( list(range(0,25,5)) )
# ```
# If we need it, we can also set up blank lists.
# ```js
# print ([])
# ```
# ## Modifying Lists:
# The simplest change we can make to a list is to change it at a specific index just be redefining it, like in the second line in the code below.
# ```js
# x=list(range(1,6))
# print(x)
# print(x[2])
# x[2]=8
# print(x[2])
# print(x)
# ```
#
# There's three other handy ways to modify a list. "Append" will add whatever we want as the next item in the list, but this means if we're adding more than a single value, it will add a list into our list, which may not always be what we want.
# ```js
# print ("Testing append")
# x.append(6)
# print (x)
# x.append([7,8])
# print (x)
# ```
#
# extend will expand the list to include the additional values, but only if it's a list, it won't work on a single integer (go ahead and try that).
# ```js
# print ("testing extend")
# x=list(range(1,6))
# # x.extend(6) #<--- won't work
# print (x)
# x.extend([7,8])
# print (x)
# ```
#
# ## Index Slicing
# Sometimes, you may only want a small portion of a list or array. You can do that with the use of square brackets [:].
#
# ```js
# x=list(range(1,11))
# print(x)
#
# print(x[0:3])  #first 4 elements of x list
#
# print(x[5:9])  # prints 6th to 10th elements
#
# print(x[0::2]) #every 2 elements of x list, starting from first element
#
# print(x[::-1]) #reverses the order of x list
# ```
#
# Finally, insert will let us insert a value anywhere within the list. To do this, it requires a number for what spot in the list it should go, and also what we want to add into the list.
#
# ## Loops and List comprehension:
# Like most languages, we can write loops in Python which allow you to iterate over indices of a list and perform whatever operations you'd like on each one. One of the most standard loops is a for loop, so we'll focus on that one. Below is a 'standard' way of writing a 'for' loop. We'll do something simple, where all we want is to get the square of each number in the array.
# ```js
# x=list(range(1,11,1))
# print (x)
# x_2=[]
# for i in x:
#     i_2=i**2 #note: to raise something to the Nth power, use ** instead of ^
#     x_2.append(i_2)
# print (x_2)
# ```
#
# While that loop works, even this pretty simple example can be condensed into something a bit shorter. We have to set up a blank list, and then after that, the loop itself was 3 lines, so just getting the squares of all these values took 4 lines. We can do it in one with list comprehension.
#
# This is basically a different way of writing a for loop, and will return a list, so we don't have to set up an empty list for the results.
#
# ```js
# x=list(range(1,11,1))
# print (x)
# x_2=[i**2 for i in x]
# print (x_2)
# ```
#
# ## Dictionaries:
# Dictionaries are another way of storing a large amount of data in Python, except instead of being referenced by an ordered set of numbers like in a list, they are referenced by either strings/characters or numbers, referred to as keys.
# ```js
# x={}
# x['answer']=42
# print(x['answer'])
# ```
# These are particularly useful if you'll have a handful of values you'd like to call back to often. For an astronomy example, we can set up a dictionary that contains the absolute magnitude of the Sun in a bunch of bands (from Binney & Merrifield). We can now have a code that easily calls absolute magnitudes whenever needed using that dictionary.
#
# We can also list out the dictionary, if needed, with AbMag.items(), see our keys with AbMag.keys() or values with AbMag.values(). There's some other tools for more advanced tricks with dictionaries, but this covers the basics.
# ```js
# AbMag={'U':5.61, 'B':5.48, 'V':4.83, 'R':4.42, 'I':4.08}
# print (AbMag['U'])
# print (AbMag.items())
# print (AbMag.keys())
# print (AbMag.values())
# ```
#
# ## Arrays:
# Arrays are very similar to lists except that you cannot perform mathematical operations on lists. To use arrays, we'll first need to import our first Python module, Numpy. You can nickname your imports for shorthanded versions (in this case np).
#
# ```js
# import numpy as np
# x=np.array(range(0,12,2))
# print(x/2)
# y=list(range(0,12,2))
# print(y/3) #<--- will not work
# ```
#
# A REALLY useful thing to ALWAYS check is the length of your lists/arrays. Often when trying to perform a mathematical operation or plot two lists/arrays that are of different lengths, you'll get an error. You can check list/array lengths like so:
#
# ```js
# print(len(x))
# ```

# %% [markdown]
# # 5) Functions and classes
#
# ## Functions
# At a certain point you'll be writing the same bits of code over and over again. That means that if you want to update it, you'll have to update it in every single spot you did the same thing. This is.... less than optimal use of time, and it also means it's really easy to screw up by forgetting to keep one spot the same as the rest.
#
# We can try out a function by writing a crude function for the sum of a geometric series.
#
# $\frac{1}{r} + \frac{1}{r^2} + \frac{1}{r^3}+ \frac{1}{r^4} + ...$
#
# Conveniently, so long as r is larger than 1, there's a known solution to this series. We can use that to see that this function works.
#
# $\frac{1}{r-1}$
#
# This means we can call the function repeatedly and not need to change anything. In this case, you can try using this GeoSum function for several different numbers (remember, r>1), and see how closely this works, by just changing TermValue
#
# ```js
# def GeoSum(r):
#     powers=range(1,11,1) #set up a list for the exponents 1 to 10
#     terms=[(1./(r**x)) for x in powers] #calculate each term in the series
#     return sum(terms) #return the sum of the list
#
# TermValue=2
# print (GeoSum(TermValue), (1.)/(TermValue-1))
# ```
#
# ## Classes
# With a class, we can create an object with a whole set of properties that we can access. This can be very useful when you want to deal with many objects with the same set of parameters, rather than trying to keep track of related variables over multiple lists, or even just having a single object's properties all stored in some hard to manage list or dictionary.
#
# Here we'll just use a class that's set up to do some basic math. Note that the class consists of several smaller functions inside of it. The first function, called init, is going to be run as soon as we create an object belonging to this class, and so that'll create two attributes to that object, value and square. The other function, powerraise, only gets called if we call it. Try adding some other subfunctions in there to try this out. They don't need to have anything new passed to them to be run.
#
#
# ```js
# class SampleClass:
#     def __init__(self, value): #run on initial setup of the class, provide a value
#        self.value = value
#        self.square = value**2
#
#     def powerraise(self, powerval): #only run when we call it, provide powerval
#         self.powerval=powerval
#         self.raisedpower=self.value**powerval
#
# MyNum=SampleClass(3)
# print MyNum.value
# print MyNum.square
# MyNum.powerraise(4)
# print MyNum.powerval
# print MyNum.raisedpower
# print MyNum.value,'^',MyNum.powerval,'=',MyNum.raisedpower
# ```

# %% [markdown]
# ## 6) Plotting basics with matplotlib
#
# Let's import numpy and some commands from matplotlib:
#
# ```js
# import numpy as np
# from matplotlib import pyplot as plt
# from matplotlib import pylab
# from pylab import *
# ```
#
#
#
# To create a figure space, you can use
# ```js
# plt.figure()
# plt.show()
# ```
# To alter how big the figure will be, you can use figsize=(Width,Height) inside the figure command:
# ```js
# plt.figure(figsize=(10,6))
# plt.show()
# ```
#
# You can also add labels and titles to your figures as well with the xlabel, ylabel and title commands with the use of strings.
#
# ```js
# plt.figure(figsize=(10,6))
# plt.xlabel("X axis")
# plt.ylabel("Y axis")
# plt.title("Blanky McBlank plot")
# plt.show()
# ```
#
# Now, let's make up a realistic photometric time series.
# ```js
# ndays = 27 #days
# cadence= 2*60 #take measurement twice an hour
# pts_per_day = 24*cadence #data points per day
# scatter_frac = 0.0005  # add scatter to data to make it realistic
# ```
#
# Let's choose todays date, in Julian Date Format (5/23/2019 -> 2458625.7) as an arbitrary starting time. From here, we can use the number of days of our data set and the number of observations per day to create a list containing a start time, a stop time with a specified stepsize:
#
# ```js
# start=0.0
# stop=ndays
# stepsize=ndays*pts_per_day
# time = 2458625.7 + np.linspace(start, stop, stepsize)
# ```
#
# Now, let's create our measured brightness values in units of Flux. We can use our specified amount of scatter to add a random amount of noise. We can also create random errors values for our simulated measurements of Flux.
#
# ```js
# flux = 1.0 + np.random.randn(time.size) * scatter_frac
# fluxerr = np.ones_like(flux) * scatter_frac
# ```
#
# Now, let's plot these values:

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import pylab
from pylab import *

ndays = 27 #days
cadence= 2*60 #take measurement twice an hour
pts_per_day = 24*cadence #data points per day
scatter_frac = 0.0005  # add scatter to data to make it realistic

start=0.0
stop=ndays
stepsize=ndays*pts_per_day
time = 2458625.7 + np.linspace(start, stop, stepsize) 

flux = 1.0 + np.random.randn(time.size) * scatter_frac
fluxerr = np.ones_like(flux) * scatter_frac

plt.figure(figsize=(14,6)) #width, height
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.plot(time,flux,marker='.',color='black',linestyle='none')
plt.xlabel("Time (JD)")
plt.ylabel("Flux")
plt.title("Fake Light Curve")
plt.show()

# %% [markdown]
# If we want to see the errorbars, we can use the errorbar command from matplotlib:

# %%
plt.figure(figsize=(14,6)) #width, height
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.errorbar(time,flux,fluxerr,marker='.',color='black',linestyle='none')
plt.xlabel("Time (JD)")
plt.ylabel("Flux")
plt.title("Fake Light Curve")
plt.show()

# %% [markdown]
# This is a little tough to see the errorbars. We can zoom in a few ways.
#
# 1) using the xlim/ylim commands in pyplot by providing lower/upper bounds

# %%
plt.figure(figsize=(14,6)) #width, height
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.errorbar(time,flux,fluxerr,marker='.',color='black',linestyle='none')
plt.xlabel("Time (JD)")
plt.ylabel("Flux")
plt.title("Fake Light Curve")
plt.xlim(2458625.7,2458625.735)
plt.show()

# %% [markdown]
# 2) Using "index slicing", we can cut out all the data points outside a specified range. Let's choose the first index (element 0) up until the 101st index (element 100)
# ```js
# [0:100]
# ```

# %%
plt.figure(figsize=(14,6)) #width, height
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.errorbar(time[0:100],flux[0:100],fluxerr[0:100],marker='.',color='black',linestyle='none')
plt.xlabel("Time (JD)")
plt.ylabel("Flux")
plt.title("Fake Light Curve")
plt.show()

# %% [markdown]
# 3) using the Numpy "Where" command to find which indices are between a specified time range

# %%
time1 = 2458625.7
time2 = 2458625.735

cut = np.where( (time1<time) & (time<time2)  )[0] #a Pythonic way of finding where time1 < time < time2

newtime = time[cut]
newflux = flux[cut]
newfluxerr = fluxerr[cut]

plt.figure(figsize=(14,6)) #width, height
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.errorbar(newtime,newflux,newfluxerr,marker='.',color='black',linestyle='none')
plt.xlabel("Time (JD)")
plt.ylabel("Flux")
plt.title("Fake Light Curve")
plt.show()

# %% [markdown]
# ## It is also possible to add multiple figures on top of or next to each other with the subplot command:

# %%
fig=plt.figure(figsize=(10, 4))


#let's make random new data
aa = newflux
bb = np.sin(np.pi*newflux)
cc = np.sin(np.pi*newflux)+np.exp(newflux/0.37)

fig = plt.figure(figsize=(10,6))
fig.add_subplot(311)
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.plot(newtime,aa,'k.')
plt.title("title")
plt.xlabel("x axis")
plt.ylabel("y axis")

fig.add_subplot(312)
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.plot(newtime,bb,'k.')
plt.title("title")
plt.xlabel("x axis")
plt.ylabel("y axis")

fig.add_subplot(313)
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.plot(newtime,cc,'k.')
plt.title("title")
plt.xlabel("x axis")
plt.ylabel("y axis")
fig.subplots_adjust(hspace=0.4)
fig.tight_layout() #<--- This line ensures everything is aligned
plt.show()

# %% [markdown]
# ## You can also make different sized figures in various configurations. I think this one is particularly useful

# %%
import matplotlib.gridspec as gridspec

gs1 = gridspec.GridSpec(3, 3)
gs1.update(left=0.65, right=1.25, wspace=0.5,hspace=0.5)

fig = plt.figure(figsize=(20,6))

ax1 = fig.add_subplot(gs1[:-1, :])
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
ax2 = fig.add_subplot(gs1[-1, :-1])
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
ax3 = fig.add_subplot(gs1[-1, -1])
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False) #turns off scientific notation
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)

ax1.plot(newtime,aa,'r.')


ax1.set_title("title")
ax1.set_xlabel("x axis")
ax1.set_ylabel("y axis")

ax2.plot(newtime,bb,'g.')
ax2.set_title("title")
ax2.set_xlabel("x axis")
ax2.set_ylabel("y axis")

ax3.plot(newtime,aa,'b.')
ax3.set_title("title")
ax3.set_xlabel("x axis")
ax3.set_ylabel("y axis")

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Next time, let's start playing with real data from TESS!

# %% [markdown]
# For more tutorials on Python, see one of the Bootcamps I attended a few years ago:
#
# [https://github.com/VandyAstroML/Vanderbilt_Computational_Bootcamp/tree/master/notebooks](https://github.com/VandyAstroML/Vanderbilt_Computational_Bootcamp/tree/master/notebooks)
#
# Also,
# [https://astrofrog.github.io/py4sci/](https://astrofrog.github.io/py4sci/)
